# %%
import pandas as pd
import numpy as np

# %%
stroke = pd.read_csv(
    r"C:\Users\navee\PreStrokeNet\Datasets\interim\stroke_clean.csv"
)

keystroke = pd.read_csv(
    r"C:\Users\navee\PreStrokeNet\Datasets\interim\keystroke_clean.csv"
)

# %%
stroke.head()
keystroke.head()
# Out:
#    subject  key      H     UD     DD
# 0        2   44  0.110  0.125  0.235
# 1        2   42  0.094  0.312  0.406
# 2        2   42  0.062  0.859  0.921
# 3        2   42  0.078  0.469  0.547
# 4        2   42  0.062  0.688  0.750

# %%
stroke.info()
keystroke.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   int64
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   int64
#  6   work_type          5110 non-null   int64
#  7   Residence_type     5110 non-null   int64
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   int64
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(9)
# memory usage: 479.2 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ...

# %%
stroke.select_dtypes(include="object").columns
keystroke.select_dtypes(include="object").columns
# Out:
# Index([], dtype='str')

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

stroke["gender"] = encoder.fit_transform(stroke["gender"])
stroke["ever_married"] = encoder.fit_transform(stroke["ever_married"])
stroke["work_type"] = encoder.fit_transform(stroke["work_type"])
stroke["Residence_type"] = encoder.fit_transform(stroke["Residence_type"])
stroke["smoking_status"] = encoder.fit_transform(stroke["smoking_status"])



keystroke["subject"] = encoder.fit_transform(keystroke["subject"])
keystroke["key"] = encoder.fit_transform(keystroke["key"])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()



stroke_scaled = scaler.fit_transform(stroke.drop("stroke", axis=1))



keystroke_scaled = scaler.fit_transform(
    keystroke.drop(["subject", "key"], axis=1)
)

# %%
stroke.to_csv(
    r"C:\Users\navee\PreStrokeNet\Datasets\Processed\stroke_features.csv",
    index=False
)

keystroke.to_csv(
    r"C:\Users\navee\PreStrokeNet\Datasets\Processed\keystroke_features.csv",
    index=False
)
